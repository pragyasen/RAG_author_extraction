# %%
import re
import json
import pandas as pd
import subprocess
import requests
from pdf2image import convert_from_path
import pytesseract
from scholarly import scholarly
from difflib import SequenceMatcher

# %%
PDF_PATH = r"/References.pdf"
OCR_OUTPUT_PATH = r"/ocr_extracted.xlsx"
VERIFIED_OUTPUT_PATH = r"/verified_data.xlsx"

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
ENRICH_CACHE = {
    "author": {}, #author lookup cache
    "title_to_doi": {} #inferred DOIs cache
}
ENRICH_CACHE.setdefault("author", {})
ENRICH_CACHE.setdefault("title_to_doi", {})
CROSSREF_URL = "https://api.crossref.org/works"

# %%
def extract_text_with_ocr(pdf_path):
    images = convert_from_path(pdf_path, dpi=300)
    full_text = ""
    for img in images:
        text = pytesseract.image_to_string(img)
        full_text += text + "\n"
    return full_text

# %%
def call_ollama(prompt, model="llama3"):
    """
    Sends prompt to Ollama CLI and returns raw string output.
    """
    result = subprocess.run(
        ["ollama", "run", model],
        input=prompt.encode("utf-8"),
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE
    )
    output = result.stdout.decode("utf-8")
    if not output.strip():
        print("Warning: Ollama returned empty output")
    return output

# %%
def extract_references_with_llm(ocr_text, n_refs=1):
    """
    Extracts the first `n_refs` references from OCR text using LLaMA via Ollama.
    Handles extra explanatory text in LLaMA output and ensures valid JSON.
    Returns a list of dictionaries with keys:
    - "reference"
    - "title"
    - "first_author"
    - "last_author"
    """
    prompt = f"""
You are given the text of a PDF containing academic references. Extract the first {n_refs} references.

For each reference, output a JSON object with keys:
- "reference": the full reference text as it appears in the PDF
- "title": the title of the paper/book
- "first_author": the first author
- "last_author": the last author

Important:
- Return ONLY a JSON array.
- Do NOT include any explanation, notes, or extra text.
- DO NOT start the array with any other text.
- Ensure all strings use double quotes (") for keys and values.
- If you cannot extract some fields, leave them as empty strings.

PDF text:
{ocr_text}
"""

    #calling Ollama CLI
    result = subprocess.run(
        ["ollama", "run", "llama3"],
        input=prompt.encode("utf-8"),
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE
    )
    response = result.stdout.decode()

    #JSON extraction
    match = re.search(r'\[.*\]', response, re.DOTALL)
    if match:
        try:
            refs = json.loads(match.group())
        except json.JSONDecodeError:
            print("Failed to decode JSON. Saving raw response to llama_raw_output.txt")
            with open("llama_raw_output.txt", "w", encoding="utf-8") as f:
                f.write(response)
            refs = []
    else:
        print("No JSON array found. Saving raw response to llama_raw_output.txt")
        with open("llama_raw_output.txt", "w", encoding="utf-8") as f:
            f.write(response)
        refs = []

    #ensuring all expected keys exist
    for r in refs:
        for key in ["reference", "title", "first_author", "last_author"]:
            if key not in r:
                r[key] = ""

    return refs

# %%
#DuckDuckGo search
def search_duckduckgo(query):
    try:
        url = "https://api.duckduckgo.com/"
        resp = requests.get(url, params={"q": query, "format": "json"}, timeout=8)
        data = resp.json()
        snippet = data.get("AbstractText") or data.get("Heading") or ""
        snippet = snippet.strip()
        return snippet if snippet else ""
    except Exception:
        return ""

# %%
#fuzzy match author name
def similar(a, b):
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

# %%
#cached lookup wrapper
def cached_lookup(key, cache, fn, *args):
    if key in cache:
        return cache[key]
    val = fn(*args)
    cache[key] = val
    return val

# %%
#inferring DOI from title
def infer_doi(title):
    if title in ENRICH_CACHE["title_to_doi"]:
        return ENRICH_CACHE["title_to_doi"][title]

    try:
        resp = requests.get(
            CROSSREF_URL,
            params={"query.bibliographic": title, "rows": 1},
            timeout=10
        )
        data = resp.json()
        items = data["message"]["items"]
        if items:
            doi = items[0].get("DOI", "")
            ENRICH_CACHE["title_to_doi"][title] = doi
            return doi
    except Exception:
        pass

    ENRICH_CACHE["title_to_doi"][title] = ""
    return ""

# %%
#main enrichment
def enrich_data_full_with_ddg(extracted_refs):
    enriched_rows = []

    for r in extracted_refs:
        fa = r["first_author"]
        la = r["last_author"]
        title = r["title"]

        #default empty
        best = {
            "fa_aff": "",
            "fa_email": "",
            "la_aff": "",
            "la_email": "",
        }
        
        #Google Scholar (highest trust)
        def lookup_author_scholar(name):
            try:
                q = scholarly.search_author(name)
                author = next(q)
                scholarly.fill(author)
                aff = author.affiliation or ""
                email = getattr(author, "email", "") or ""
                return aff, email
            except Exception:
                return "", ""

        fa_aff, fa_email = cached_lookup(f"scholar_{fa}", ENRICH_CACHE["author"], lookup_author_scholar, fa)
        la_aff, la_email = cached_lookup(f"scholar_{la}", ENRICH_CACHE["author"], lookup_author_scholar, la)

        if fa_aff: best["fa_aff"] = fa_aff
        if fa_email: best["fa_email"] = fa_email
        if la_aff: best["la_aff"] = la_aff
        if la_email: best["la_email"] = la_email

        #CrossRef (mid trust)
        doi = infer_doi(title)
        if doi:
            try:
                resp = requests.get(f"{CROSSREF_URL}/{doi}", timeout=10)
                data = resp.json()
                authors = data["message"].get("author", [])

                for a in authors:
                    fam = a.get("family", "")
                    aff = a.get("affiliation", [])
                    aff = aff[0]["name"] if aff else ""

                    if similar(fam, fa.split()[-1]) > 0.7:
                        if aff and not best["fa_aff"]:
                            best["fa_aff"] = aff

                    if similar(fam, la.split()[-1]) > 0.7:
                        if aff and not best["la_aff"]:
                            best["la_aff"] = aff
            except Exception:
                pass

        #DuckDuckGo (low trust; sanitized)
        def lookup_ddg(name):
            snippet = search_duckduckgo(f"{name} researcher affiliation university email")
            if not snippet:
                return "", ""

            snippet_clean = snippet.replace("\n", " ").strip()

            email_match = re.search(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}", snippet_clean)
            email = email_match.group(0) if email_match else ""

            return snippet_clean, email

        if not best["fa_aff"] or not best["fa_email"]:
            ddg_aff, ddg_email = cached_lookup(f"ddg_{fa}", ENRICH_CACHE["author"], lookup_ddg, fa)
            if ddg_aff and not best["fa_aff"]:
                best["fa_aff"] = ddg_aff
            if ddg_email and not best["fa_email"]:
                best["fa_email"] = ddg_email

        if not best["la_aff"] or not best["la_email"]:
            ddg_aff, ddg_email = cached_lookup(f"ddg_{la}", ENRICH_CACHE["author"], lookup_ddg, la)
            if ddg_aff and not best["la_aff"]:
                best["la_aff"] = ddg_aff
            if ddg_email and not best["la_email"]:
                best["la_email"] = ddg_email

        #LLaMA inference fallback (lowest trust)
        if "" in best.values():
            prompt = f"""
Infer affiliations/emails for:
Title: "{title}"
Authors: "{fa}", "{la}"
Return ONLY JSON:
{{
"first_author_affiliation": "",
"first_author_email": "",
"last_author_affiliation": "",
"last_author_email": ""
}}
"""
            try:
                out = subprocess.run(
                    ["ollama", "run", "llama3"],
                    input=prompt.encode(),
                    stdout=subprocess.PIPE
                )
                text = out.stdout.decode()
                match = re.search(r"\{.*\}", text, re.DOTALL)
                enrich = json.loads(match.group()) if match else {}
            except Exception:
                enrich = {}

            if not best["fa_aff"]:
                best["fa_aff"] = enrich.get("first_author_affiliation", "")
            if not best["fa_email"]:
                best["fa_email"] = enrich.get("first_author_email", "")
            if not best["la_aff"]:
                best["la_aff"] = enrich.get("last_author_affiliation", "")
            if not best["la_email"]:
                best["la_email"] = enrich.get("last_author_email", "")

        #applying final values
        r.update({
            "first_author_affiliation": best["fa_aff"],
            "first_author_email": best["fa_email"],
            "last_author_affiliation": best["la_aff"],
            "last_author_email": best["la_email"]
        })

        enriched_rows.append(r)

    return enriched_rows

# %%
print("Step 1: Extracting text from PDF using OCR")
ocr_text = extract_text_with_ocr(PDF_PATH)

#cleaning OCR text
#replacing curly quotes
ocr_text_clean = ocr_text.replace("’", "'").replace("‘", "'")
#merging wrapped lines that aren't new references
ocr_text_clean = re.sub(r"\n(?=[^\[])", " ", ocr_text_clean)

#extracting all references
refs_matches = re.findall(
    r'\[[^\]]+?\].*?(?=\[[^\]]+?\]|$)',
    ocr_text_clean,
    re.DOTALL
)

print(f"Found {len(refs_matches)} references in PDF.")

#parsing each reference individually
print("Step 2: Parsing references with LLaMA via Ollama")

extracted_refs = []
for i, ref in enumerate(refs_matches):
    print(f"  → Parsing reference {i+1}/{len(refs_matches)}...")
    parsed = extract_references_with_llm(ref, n_refs=1)
    if parsed:
        extracted_refs.extend(parsed)

#saving first Excel (raw parsed references)
df_ocr = pd.DataFrame(extracted_refs)
df_ocr.to_excel(OCR_OUTPUT_PATH, index=False)
print(f"Saved first Excel → {OCR_OUTPUT_PATH}")

#enriching with web enhancement
print("Step 3: Enriching with affiliations and emails")
verified_refs = enrich_data_full_with_ddg(extracted_refs)

#saving enriched Excel
df_verified = pd.DataFrame(verified_refs)
df_verified.to_excel(VERIFIED_OUTPUT_PATH, index=False)
print(f"Saved second Excel → {VERIFIED_OUTPUT_PATH}")

print("\nDONE - two separate Excel files generated successfully.")
# Out:
# Step 1: Extracting text from PDF using OCR
# Found 614 references in PDF.
# Step 2: Parsing references with LLaMA via Ollama
#   → Parsing reference 1/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 2/614...
#   → Parsing reference 3/614...
#   → Parsing reference 4/614...
#   → Parsing reference 5/614...
#   → Parsing reference 6/614...
#   → Parsing reference 7/614...
#   → Parsing reference 8/614...
#   → Parsing reference 9/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 10/614...
#   → Parsing reference 11/614...
#   → Parsing reference 12/614...
#   → Parsing reference 13/614...
#   → Parsing reference 14/614...
#   → Parsing reference 15/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 16/614...
#   → Parsing reference 17/614...
#   → Parsing reference 18/614...
#   → Parsing reference 19/614...
#   → Parsing reference 20/614...
#   → Parsing reference 21/614...
#   → Parsing reference 22/614...
#   → Parsing reference 23/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 24/614...
#   → Parsing reference 25/614...
#   → Parsing reference 26/614...
#   → Parsing reference 27/614...
#   → Parsing reference 28/614...
#   → Parsing reference 29/614...
#   → Parsing reference 30/614...
#   → Parsing reference 31/614...
#   → Parsing reference 32/614...
#   → Parsing reference 33/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 34/614...
#   → Parsing reference 35/614...
#   → Parsing reference 36/614...
#   → Parsing reference 37/614...
#   → Parsing reference 38/614...
#   → Parsing reference 39/614...
#   → Parsing reference 40/614...
#   → Parsing reference 41/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 42/614...
#   → Parsing reference 43/614...
#   → Parsing reference 44/614...
#   → Parsing reference 45/614...
#   → Parsing reference 46/614...
#   → Parsing reference 47/614...
#   → Parsing reference 48/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 49/614...
#   → Parsing reference 50/614...
#   → Parsing reference 51/614...
#   → Parsing reference 52/614...
#   → Parsing reference 53/614...
#   → Parsing reference 54/614...
#   → Parsing reference 55/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 56/614...
#   → Parsing reference 57/614...
#   → Parsing reference 58/614...
#   → Parsing reference 59/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 60/614...
#   → Parsing reference 61/614...
#   → Parsing reference 62/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 63/614...
#   → Parsing reference 64/614...
#   → Parsing reference 65/614...
#   → Parsing reference 66/614...
#   → Parsing reference 67/614...
#   → Parsing reference 68/614...
#   → Parsing reference 69/614...
#   → Parsing reference 70/614...
#   → Parsing reference 71/614...
#   → Parsing reference 72/614...
#   → Parsing reference 73/614...
#   → Parsing reference 74/614...
#   → Parsing reference 75/614...
#   → Parsing reference 76/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 77/614...
#   → Parsing reference 78/614...
#   → Parsing reference 79/614...
#   → Parsing reference 80/614...
#   → Parsing reference 81/614...
#   → Parsing reference 82/614...
#   → Parsing reference 83/614...
#   → Parsing reference 84/614...
#   → Parsing reference 85/614...
#   → Parsing reference 86/614...
#   → Parsing reference 87/614...
#   → Parsing reference 88/614...
#   → Parsing reference 89/614...
#   → Parsing reference 90/614...
#   → Parsing reference 91/614...
#   → Parsing reference 92/614...
#   → Parsing reference 93/614...
#   → Parsing reference 94/614...
#   → Parsing reference 95/614...
#   → Parsing reference 96/614...
#   → Parsing reference 97/614...
#   → Parsing reference 98/614...
#   → Parsing reference 99/614...
#   → Parsing reference 100/614...
#   → Parsing reference 101/614...
#   → Parsing reference 102/614...
#   → Parsing reference 103/614...
#   → Parsing reference 104/614...
#   → Parsing reference 105/614...
#   → Parsing reference 106/614...
#   → Parsing reference 107/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 108/614...
#   → Parsing reference 109/614...
#   → Parsing reference 110/614...
#   → Parsing reference 111/614...
#   → Parsing reference 112/614...
#   → Parsing reference 113/614...
#   → Parsing reference 114/614...
#   → Parsing reference 115/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 116/614...
#   → Parsing reference 117/614...
#   → Parsing reference 118/614...
#   → Parsing reference 119/614...
#   → Parsing reference 120/614...
#   → Parsing reference 121/614...
#   → Parsing reference 122/614...
#   → Parsing reference 123/614...
#   → Parsing reference 124/614...
#   → Parsing reference 125/614...
#   → Parsing reference 126/614...
#   → Parsing reference 127/614...
#   → Parsing reference 128/614...
#   → Parsing reference 129/614...
#   → Parsing reference 130/614...
#   → Parsing reference 131/614...
#   → Parsing reference 132/614...
#   → Parsing reference 133/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 134/614...
#   → Parsing reference 135/614...
#   → Parsing reference 136/614...
#   → Parsing reference 137/614...
#   → Parsing reference 138/614...
#   → Parsing reference 139/614...
#   → Parsing reference 140/614...
#   → Parsing reference 141/614...
#   → Parsing reference 142/614...
#   → Parsing reference 143/614...
#   → Parsing reference 144/614...
#   → Parsing reference 145/614...
#   → Parsing reference 146/614...
#   → Parsing reference 147/614...
#   → Parsing reference 148/614...
#   → Parsing reference 149/614...
#   → Parsing reference 150/614...
#   → Parsing reference 151/614...
#   → Parsing reference 152/614...
#   → Parsing reference 153/614...
#   → Parsing reference 154/614...
#   → Parsing reference 155/614...
#   → Parsing reference 156/614...
#   → Parsing reference 157/614...
#   → Parsing reference 158/614...
#   → Parsing reference 159/614...
#   → Parsing reference 160/614...
#   → Parsing reference 161/614...
#   → Parsing reference 162/614...
#   → Parsing reference 163/614...
#   → Parsing reference 164/614...
#   → Parsing reference 165/614...
#   → Parsing reference 166/614...
#   → Parsing reference 167/614...
#   → Parsing reference 168/614...
#   → Parsing reference 169/614...
#   → Parsing reference 170/614...
#   → Parsing reference 171/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 172/614...
#   → Parsing reference 173/614...
#   → Parsing reference 174/614...
#   → Parsing reference 175/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 176/614...
#   → Parsing reference 177/614...
#   → Parsing reference 178/614...
#   → Parsing reference 179/614...
#   → Parsing reference 180/614...
#   → Parsing reference 181/614...
#   → Parsing reference 182/614...
#   → Parsing reference 183/614...
#   → Parsing reference 184/614...
#   → Parsing reference 185/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 186/614...
#   → Parsing reference 187/614...
#   → Parsing reference 188/614...
#   → Parsing reference 189/614...
#   → Parsing reference 190/614...
#   → Parsing reference 191/614...
#   → Parsing reference 192/614...
#   → Parsing reference 193/614...
#   → Parsing reference 194/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 195/614...
#   → Parsing reference 196/614...
#   → Parsing reference 197/614...
#   → Parsing reference 198/614...
#   → Parsing reference 199/614...
#   → Parsing reference 200/614...
#   → Parsing reference 201/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 202/614...
#   → Parsing reference 203/614...
#   → Parsing reference 204/614...
#   → Parsing reference 205/614...
#   → Parsing reference 206/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 207/614...
#   → Parsing reference 208/614...
#   → Parsing reference 209/614...
#   → Parsing reference 210/614...
#   → Parsing reference 211/614...
#   → Parsing reference 212/614...
#   → Parsing reference 213/614...
#   → Parsing reference 214/614...
#   → Parsing reference 215/614...
#   → Parsing reference 216/614...
#   → Parsing reference 217/614...
#   → Parsing reference 218/614...
#   → Parsing reference 219/614...
#   → Parsing reference 220/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 221/614...
#   → Parsing reference 222/614...
#   → Parsing reference 223/614...
#   → Parsing reference 224/614...
#   → Parsing reference 225/614...
#   → Parsing reference 226/614...
#   → Parsing reference 227/614...
#   → Parsing reference 228/614...
#   → Parsing reference 229/614...
#   → Parsing reference 230/614...
#   → Parsing reference 231/614...
#   → Parsing reference 232/614...
#   → Parsing reference 233/614...
#   → Parsing reference 234/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 235/614...
#   → Parsing reference 236/614...
#   → Parsing reference 237/614...
#   → Parsing reference 238/614...
#   → Parsing reference 239/614...
#   → Parsing reference 240/614...
#   → Parsing reference 241/614...
#   → Parsing reference 242/614...
#   → Parsing reference 243/614...
#   → Parsing reference 244/614...
#   → Parsing reference 245/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 246/614...
#   → Parsing reference 247/614...
#   → Parsing reference 248/614...
#   → Parsing reference 249/614...
#   → Parsing reference 250/614...
#   → Parsing reference 251/614...
#   → Parsing reference 252/614...
#   → Parsing reference 253/614...
#   → Parsing reference 254/614...
#   → Parsing reference 255/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 256/614...
#   → Parsing reference 257/614...
#   → Parsing reference 258/614...
#   → Parsing reference 259/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 260/614...
#   → Parsing reference 261/614...
#   → Parsing reference 262/614...
#   → Parsing reference 263/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 264/614...
#   → Parsing reference 265/614...
#   → Parsing reference 266/614...
#   → Parsing reference 267/614...
#   → Parsing reference 268/614...
#   → Parsing reference 269/614...
#   → Parsing reference 270/614...
#   → Parsing reference 271/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 272/614...
#   → Parsing reference 273/614...
#   → Parsing reference 274/614...
#   → Parsing reference 275/614...
#   → Parsing reference 276/614...
#   → Parsing reference 277/614...
#   → Parsing reference 278/614...
#   → Parsing reference 279/614...
#   → Parsing reference 280/614...
#   → Parsing reference 281/614...
#   → Parsing reference 282/614...
#   → Parsing reference 283/614...
#   → Parsing reference 284/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 285/614...
#   → Parsing reference 286/614...
#   → Parsing reference 287/614...
#   → Parsing reference 288/614...
#   → Parsing reference 289/614...
#   → Parsing reference 290/614...
#   → Parsing reference 291/614...
#   → Parsing reference 292/614...
#   → Parsing reference 293/614...
#   → Parsing reference 294/614...
#   → Parsing reference 295/614...
#   → Parsing reference 296/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 297/614...
#   → Parsing reference 298/614...
#   → Parsing reference 299/614...
#   → Parsing reference 300/614...
#   → Parsing reference 301/614...
#   → Parsing reference 302/614...
#   → Parsing reference 303/614...
#   → Parsing reference 304/614...
#   → Parsing reference 305/614...
#   → Parsing reference 306/614...
#   → Parsing reference 307/614...
#   → Parsing reference 308/614...
#   → Parsing reference 309/614...
#   → Parsing reference 310/614...
#   → Parsing reference 311/614...
#   → Parsing reference 312/614...
#   → Parsing reference 313/614...
#   → Parsing reference 314/614...
#   → Parsing reference 315/614...
#   → Parsing reference 316/614...
#   → Parsing reference 317/614...
#   → Parsing reference 318/614...
#   → Parsing reference 319/614...
#   → Parsing reference 320/614...
#   → Parsing reference 321/614...
#   → Parsing reference 322/614...
#   → Parsing reference 323/614...
#   → Parsing reference 324/614...
#   → Parsing reference 325/614...
#   → Parsing reference 326/614...
#   → Parsing reference 327/614...
#   → Parsing reference 328/614...
#   → Parsing reference 329/614...
#   → Parsing reference 330/614...
#   → Parsing reference 331/614...
#   → Parsing reference 332/614...
#   → Parsing reference 333/614...
#   → Parsing reference 334/614...
#   → Parsing reference 335/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 336/614...
#   → Parsing reference 337/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 338/614...
#   → Parsing reference 339/614...
#   → Parsing reference 340/614...
#   → Parsing reference 341/614...
#   → Parsing reference 342/614...
#   → Parsing reference 343/614...
#   → Parsing reference 344/614...
#   → Parsing reference 345/614...
#   → Parsing reference 346/614...
#   → Parsing reference 347/614...
#   → Parsing reference 348/614...
#   → Parsing reference 349/614...
#   → Parsing reference 350/614...
#   → Parsing reference 351/614...
#   → Parsing reference 352/614...
#   → Parsing reference 353/614...
#   → Parsing reference 354/614...
#   → Parsing reference 355/614...
#   → Parsing reference 356/614...
#   → Parsing reference 357/614...
#   → Parsing reference 358/614...
#   → Parsing reference 359/614...
#   → Parsing reference 360/614...
#   → Parsing reference 361/614...
#   → Parsing reference 362/614...
#   → Parsing reference 363/614...
#   → Parsing reference 364/614...
#   → Parsing reference 365/614...
#   → Parsing reference 366/614...
#   → Parsing reference 367/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 368/614...
#   → Parsing reference 369/614...
#   → Parsing reference 370/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 371/614...
#   → Parsing reference 372/614...
#   → Parsing reference 373/614...
#   → Parsing reference 374/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 375/614...
#   → Parsing reference 376/614...
#   → Parsing reference 377/614...
#   → Parsing reference 378/614...
#   → Parsing reference 379/614...
#   → Parsing reference 380/614...
#   → Parsing reference 381/614...
#   → Parsing reference 382/614...
#   → Parsing reference 383/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 384/614...
#   → Parsing reference 385/614...
#   → Parsing reference 386/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 387/614...
#   → Parsing reference 388/614...
#   → Parsing reference 389/614...
#   → Parsing reference 390/614...
#   → Parsing reference 391/614...
#   → Parsing reference 392/614...
#   → Parsing reference 393/614...
#   → Parsing reference 394/614...
#   → Parsing reference 395/614...
#   → Parsing reference 396/614...
#   → Parsing reference 397/614...
#   → Parsing reference 398/614...
#   → Parsing reference 399/614...
#   → Parsing reference 400/614...
#   → Parsing reference 401/614...
#   → Parsing reference 402/614...
#   → Parsing reference 403/614...
#   → Parsing reference 404/614...
#   → Parsing reference 405/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 406/614...
#   → Parsing reference 407/614...
#   → Parsing reference 408/614...
#   → Parsing reference 409/614...
#   → Parsing reference 410/614...
#   → Parsing reference 411/614...
#   → Parsing reference 412/614...
#   → Parsing reference 413/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 414/614...
#   → Parsing reference 415/614...
#   → Parsing reference 416/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 417/614...
#   → Parsing reference 418/614...
#   → Parsing reference 419/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 420/614...
#   → Parsing reference 421/614...
#   → Parsing reference 422/614...
#   → Parsing reference 423/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 424/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 425/614...
#   → Parsing reference 426/614...
#   → Parsing reference 427/614...
#   → Parsing reference 428/614...
#   → Parsing reference 429/614...
#   → Parsing reference 430/614...
#   → Parsing reference 431/614...
#   → Parsing reference 432/614...
#   → Parsing reference 433/614...
#   → Parsing reference 434/614...
#   → Parsing reference 435/614...
#   → Parsing reference 436/614...
#   → Parsing reference 437/614...
#   → Parsing reference 438/614...
#   → Parsing reference 439/614...
#   → Parsing reference 440/614...
#   → Parsing reference 441/614...
#   → Parsing reference 442/614...
#   → Parsing reference 443/614...
#   → Parsing reference 444/614...
#   → Parsing reference 445/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 446/614...
#   → Parsing reference 447/614...
#   → Parsing reference 448/614...
#   → Parsing reference 449/614...
#   → Parsing reference 450/614...
#   → Parsing reference 451/614...
#   → Parsing reference 452/614...
#   → Parsing reference 453/614...
#   → Parsing reference 454/614...
#   → Parsing reference 455/614...
#   → Parsing reference 456/614...
#   → Parsing reference 457/614...
#   → Parsing reference 458/614...
#   → Parsing reference 459/614...
#   → Parsing reference 460/614...
#   → Parsing reference 461/614...
#   → Parsing reference 462/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 463/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 464/614...
#   → Parsing reference 465/614...
#   → Parsing reference 466/614...
#   → Parsing reference 467/614...
#   → Parsing reference 468/614...
#   → Parsing reference 469/614...
#   → Parsing reference 470/614...
#   → Parsing reference 471/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 472/614...
#   → Parsing reference 473/614...
#   → Parsing reference 474/614...
#   → Parsing reference 475/614...
#   → Parsing reference 476/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 477/614...
#   → Parsing reference 478/614...
#   → Parsing reference 479/614...
#   → Parsing reference 480/614...
#   → Parsing reference 481/614...
#   → Parsing reference 482/614...
#   → Parsing reference 483/614...
#   → Parsing reference 484/614...
#   → Parsing reference 485/614...
#   → Parsing reference 486/614...
#   → Parsing reference 487/614...
#   → Parsing reference 488/614...
#   → Parsing reference 489/614...
#   → Parsing reference 490/614...
#   → Parsing reference 491/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 492/614...
#   → Parsing reference 493/614...
#   → Parsing reference 494/614...
#   → Parsing reference 495/614...
#   → Parsing reference 496/614...
#   → Parsing reference 497/614...
#   → Parsing reference 498/614...
#   → Parsing reference 499/614...
#   → Parsing reference 500/614...
#   → Parsing reference 501/614...
#   → Parsing reference 502/614...
#   → Parsing reference 503/614...
#   → Parsing reference 504/614...
#   → Parsing reference 505/614...
#   → Parsing reference 506/614...
#   → Parsing reference 507/614...
#   → Parsing reference 508/614...
#   → Parsing reference 509/614...
#   → Parsing reference 510/614...
#   → Parsing reference 511/614...
#   → Parsing reference 512/614...
#   → Parsing reference 513/614...
#   → Parsing reference 514/614...
#   → Parsing reference 515/614...
#   → Parsing reference 516/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 517/614...
#   → Parsing reference 518/614...
#   → Parsing reference 519/614...
#   → Parsing reference 520/614...
#   → Parsing reference 521/614...
#   → Parsing reference 522/614...
#   → Parsing reference 523/614...
#   → Parsing reference 524/614...
#   → Parsing reference 525/614...
#   → Parsing reference 526/614...
#   → Parsing reference 527/614...
#   → Parsing reference 528/614...
#   → Parsing reference 529/614...
#   → Parsing reference 530/614...
#   → Parsing reference 531/614...
#   → Parsing reference 532/614...
#   → Parsing reference 533/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 534/614...
#   → Parsing reference 535/614...
#   → Parsing reference 536/614...
#   → Parsing reference 537/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 538/614...
#   → Parsing reference 539/614...
#   → Parsing reference 540/614...
#   → Parsing reference 541/614...
#   → Parsing reference 542/614...
#   → Parsing reference 543/614...
#   → Parsing reference 544/614...
#   → Parsing reference 545/614...
#   → Parsing reference 546/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 547/614...
#   → Parsing reference 548/614...
#   → Parsing reference 549/614...
#   → Parsing reference 550/614...
#   → Parsing reference 551/614...
#   → Parsing reference 552/614...
#   → Parsing reference 553/614...
#   → Parsing reference 554/614...
#   → Parsing reference 555/614...
#   → Parsing reference 556/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 557/614...
#   → Parsing reference 558/614...
#   → Parsing reference 559/614...
#   → Parsing reference 560/614...
#   → Parsing reference 561/614...
#   → Parsing reference 562/614...
#   → Parsing reference 563/614...
#   → Parsing reference 564/614...
#   → Parsing reference 565/614...
#   → Parsing reference 566/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 567/614...
#   → Parsing reference 568/614...
#   → Parsing reference 569/614...
#   → Parsing reference 570/614...
#   → Parsing reference 571/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 572/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 573/614...
#   → Parsing reference 574/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 575/614...
#   → Parsing reference 576/614...
#   → Parsing reference 577/614...
#   → Parsing reference 578/614...
#   → Parsing reference 579/614...
#   → Parsing reference 580/614...
#   → Parsing reference 581/614...
#   → Parsing reference 582/614...
#   → Parsing reference 583/614...
#   → Parsing reference 584/614...
#   → Parsing reference 585/614...
#   → Parsing reference 586/614...
#   → Parsing reference 587/614...
#   → Parsing reference 588/614...
#   → Parsing reference 589/614...
#   → Parsing reference 590/614...
#   → Parsing reference 591/614...
#   → Parsing reference 592/614...
#   → Parsing reference 593/614...
#   → Parsing reference 594/614...
#   → Parsing reference 595/614...
#   → Parsing reference 596/614...
#   → Parsing reference 597/614...
#   → Parsing reference 598/614...
#   → Parsing reference 599/614...
#   → Parsing reference 600/614...
#   → Parsing reference 601/614...
#   → Parsing reference 602/614...
#   → Parsing reference 603/614...
#   → Parsing reference 604/614...
# Failed to decode JSON. Saving raw response to llama_raw_output.txt
#   → Parsing reference 605/614...
#   → Parsing reference 606/614...
#   → Parsing reference 607/614...
#   → Parsing reference 608/614...
#   → Parsing reference 609/614...
#   → Parsing reference 610/614...
#   → Parsing reference 611/614...
#   → Parsing reference 612/614...
#   → Parsing reference 613/614...
#   → Parsing reference 614/614...
# Saved first Excel → C:\Users\pragy\OneDrive\Desktop\Fall2025\767_Adv_ML\ocr_extracted.xlsx
# Step 3: Enriching with affiliations and emails
# Saved second Excel → C:\Users\pragy\OneDrive\Desktop\Fall2025\767_Adv_ML\verified_data.xlsx
#
# DONE - two separate Excel files generated successfully.
